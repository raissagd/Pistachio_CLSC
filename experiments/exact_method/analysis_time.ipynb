# %%
import sys
sys.path.append(r'C:\Users\Lenovo\Documents\IC')
import numpy as np

# %%
def percentage_difference(value1, value2):
    if value1 == value2:
        print("Both values are equal.")
        return
        
    difference = abs(value1 - value2)
    average = (value1 + value2) / 2
    percentage_diff = (difference / average) * 100
        
    if value1 > value2:
        print(f"+{percentage_diff:.2f}%")
    else:
        print(f"-{percentage_diff:.2f}%")

# %%
avg_time_100 = 116
gurobi_time_100 = 261

percentage_difference(avg_time_100, gurobi_time_100)
# Out:
# -76.92%

# %%
avg_time_200 = 259
gurobi_time_100 = 3834

percentage_difference(avg_time_100, gurobi_time_100)
# Out:
# -188.25%

# %%
avg_time_400 = 757
gurobi_time_400 = 70339

percentage_difference(avg_time_400, gurobi_time_400)
# Out:
# -195.74%

# %%
avg_time_800 = 4120
gurobi_time_800 = 11836

percentage_difference(avg_time_800, gurobi_time_800)
# Out:
# -96.72%
