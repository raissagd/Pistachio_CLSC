# %%
import pandas as pd

# %% [markdown]
# ## Gurobi's execution times and answers

# %%
data_1 = {
    "Problem Size": [100, 200, 400, 800, 1600],
    "Time (s)": [261, 3834, 70339, 11836, 17],
    "Time (hours)": ["4.35 minutes", "1h04", "19h33", "3h30", "-"],
    "FX": ["70.598.782", "137.535.570", "270.662.193", "547.200.537", "-"]
}

df_1 = pd.DataFrame(data_1)

styled_df_1 = df_1.style.format({
}).set_properties(**{
    'text-align': 'center',
    'border': '1px solid black',
    'color': 'black',
    'background-color': '#ffffff'
}).set_table_styles([
    {
        'selector': 'th',
        'props': [
            ('border', '1px solid black'),
            ('background-color', '#f2f2f2'),
            ('color', 'black')
        ]
    },
    {
        'selector': 'td',
        'props': [
            ('color', 'black')
        ]
    }
])

styled_df_1
# Out:
# <style type="text/css">
# #T_cc5a7 th {
#   border: 1px solid black;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_cc5a7 td {
#   color: black;
# }
# #T_cc5a7_row0_col0, #T_cc5a7_row0_col1, #T_cc5a7_row0_col2, #T_cc5a7_row0_col3, #T_cc5a7_row1_col0, #T_cc5a7_row1_col1, #T_cc5a7_row1_col2, #T_cc5a7_row1_col3, #T_cc5a7_row2_col0, #T_cc5a7_row2_col1, #T_cc5a7_row2_col2, #T_cc5a7_row2_col3, #T_cc5a7_row3_col0, #T_cc5a7_row3_col1, #T_cc5a7_row3_col2, #T_cc5a7_row3_col3, #T_cc5a7_row4_col0, #T_cc5a7_row4_col1, #T_cc5a7_row4_col2, #T_cc5a7_row4_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #ffffff;
# }
# </style>
# <table id="T_cc5a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc5a7_level0_col0" class="col_heading level0 col0" >Problem Size</th>
#       <th id="T_cc5a7_level0_col1" class="col_heading level0 col1" >Time (s)</th>
# ...

# %% [markdown]
# ## VNS' execution times and answers

# %%
data_2 = {
    "Problem Size": [100, 200, 400, 800, 1600],
    "Execution time (1 instr)": ["116s", "259s", "757s", "8491s", "-"],
    "Average FX": ["74.145.040", "150.717.433", "314.007.769", "-", "-"]
}

df_2 = pd.DataFrame(data_2)

styled_df_2 = df_2.style.format({
}).set_properties(**{
    'text-align': 'center',
    'border': '1px solid black',
    'color': 'black',
    'background-color': '#ffffff'
}).set_table_styles([
    {
        'selector': 'th',
        'props': [
            ('border', '1px solid black'),
            ('background-color', '#f2f2f2'),
            ('color', 'black')
        ]
    },
    {
        'selector': 'td',
        'props': [
            ('color', 'black')
        ]
    }
])

styled_df_2
# Out:
# <style type="text/css">
# #T_26b3b th {
#   border: 1px solid black;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_26b3b td {
#   color: black;
# }
# #T_26b3b_row0_col0, #T_26b3b_row0_col1, #T_26b3b_row0_col2, #T_26b3b_row1_col0, #T_26b3b_row1_col1, #T_26b3b_row1_col2, #T_26b3b_row2_col0, #T_26b3b_row2_col1, #T_26b3b_row2_col2, #T_26b3b_row3_col0, #T_26b3b_row3_col1, #T_26b3b_row3_col2, #T_26b3b_row4_col0, #T_26b3b_row4_col1, #T_26b3b_row4_col2 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #ffffff;
# }
# </style>
# <table id="T_26b3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26b3b_level0_col0" class="col_heading level0 col0" >Problem Size</th>
#       <th id="T_26b3b_level0_col1" class="col_heading level0 col1" >Execution time (1 instr)</th>
#       <th id="T_26b3b_level0_col2" class="col_heading level0 col2" >Average FX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## Comparative: Gurobi x VNS (time and answers)

# %%
data_3 = {
    "Problem Size": [100, 200, 400, 800, 1600],
    "Average FX (%)": ["+4,90%", "+9,15%", "+14,83%", "-71,74%", "-"],
    "Average execution time (%)": ["-76,92%", "-188,25%", "-195,74%", "-71,74%", "-"]
}

df_3 = pd.DataFrame(data_3)

styled_df_3 = df_3.style.set_properties(**{
    'text-align': 'center',
    'border': '1px solid black',
    'color': 'black',
    'background-color': '#ffffff'
}).set_table_styles([
    {
        'selector': 'th',
        'props': [
            ('border', '1px solid black'),
            ('background-color', '#f2f2f2'),
            ('color', 'black')
        ]
    },
    {
        'selector': 'td',
        'props': [
            ('color', 'black')
        ]
    }
])

styled_df_3
# Out:
# <style type="text/css">
# #T_0d74a th {
#   border: 1px solid black;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_0d74a td {
#   color: black;
# }
# #T_0d74a_row0_col0, #T_0d74a_row0_col1, #T_0d74a_row0_col2, #T_0d74a_row1_col0, #T_0d74a_row1_col1, #T_0d74a_row1_col2, #T_0d74a_row2_col0, #T_0d74a_row2_col1, #T_0d74a_row2_col2, #T_0d74a_row3_col0, #T_0d74a_row3_col1, #T_0d74a_row3_col2, #T_0d74a_row4_col0, #T_0d74a_row4_col1, #T_0d74a_row4_col2 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #ffffff;
# }
# </style>
# <table id="T_0d74a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d74a_level0_col0" class="col_heading level0 col0" >Problem Size</th>
#       <th id="T_0d74a_level0_col1" class="col_heading level0 col1" >Average FX (%)</th>
#       <th id="T_0d74a_level0_col2" class="col_heading level0 col2" >Average execution time (%)</th>
#     </tr>
#   </thead>
#   <tbody>
# ...
