# %%
import numpy as np
import pandas as pd

# %%
def percentage_difference(value1, value2):
    if value1 == value2:
        print("Both values are equal.")
        return
        
    difference = abs(value1 - value2)
    average = (value1 + value2) / 2
    percentage_diff = (difference / average) * 100
        
    if value1 > value2:
        print(f"+{percentage_diff:.2f}%")
    else:
        print(f"-{percentage_diff:.2f}%")

# %%
def calculate_average(numbers):
    return sum(numbers) / len(numbers)

# %% [markdown]
# ## FX VALUE

# %% [markdown]
# ## Problem size 100

# %%
filename = './new_results/GA_100_FX.npz'
data = np.load(filename)
data_GA = data["fx_array"]

avg_GA = calculate_average(data_GA)
print(f"Average GA: {avg_GA:.2f}")
# Out:
# Average GA: 77776643.81

# %%
data = np.load("../run_parallel/new_results/script_100_fx_values.npz")['fx_array']
data_VNS = data[:30]

avg_VNS = calculate_average(data_VNS)
print(f"Average VNS: {avg_VNS:.2f}")
# Out:
# Average VNS: 74474593.85

# %%
percentage_difference(avg_GA, avg_VNS)
# Out:
# +4.34%

# %% [markdown]
# ## Problem size 200

# %%
filename = './new_results/GA_200_FX.npz'
data = np.load(filename)
data_GA = data["fx_array"]

avg_GA = calculate_average(data_GA)
print(f"Average GA: {avg_GA:.2f}")
# Out:
# Average GA: 166214321.11

# %%
data = np.load("../run_parallel/new_results/script_200_fx_values.npz")['fx_array']
data_VNS = data[:30]

avg_VNS = calculate_average(data_VNS)
print(f"Average VNS: {avg_VNS:.2f}")
# Out:
# Average VNS: 152161681.82

# %%
percentage_difference(avg_GA, avg_VNS)
# Out:
# +8.83%

# %% [markdown]
# ## Problem size 400

# %%
filename = './new_results/GA_400_FX.npz'
data = np.load(filename)
data_GA = data["fx_array"]

avg_GA = calculate_average(data_GA)
print(f"Average GA: {avg_GA:.2f}")
# Out:
# Average GA: 342109926.27

# %%
data = np.load("../run_parallel/new_results/script_400_fx_values.npz")['fx_array']
data_VNS = data[:30]

avg_VNS = calculate_average(data_VNS)
print(f"Average VNS: {avg_VNS:.2f}")
# Out:
# Average VNS: 312538139.57

# %%
percentage_difference(avg_GA, avg_VNS)
# Out:
# +9.03%

# %% [markdown]
# ## Problem size 800

# %%
filename = './new_results/GA_800_FX.npz'
data = np.load(filename)
data_GA = data["fx_array"]

avg_GA = calculate_average(data_GA)
print(f"Average GA: {avg_GA:.2f}")
# Out:
# Average GA: 707805912.18

# %%
data = np.load("../run_parallel/new_results/script_800_fx_values.npz")['fx_array']
data_VNS = data[:30]

avg_VNS = calculate_average(data_VNS)
print(f"Average VNS: {avg_VNS:.2f}")
# Out:
# Average VNS: 658957131.23

# %%
percentage_difference(avg_GA, avg_VNS)
# Out:
# +7.15%

# %% [markdown]
# ## Problem size 1600

# %%
filename = './results/solutions_1600_GA_FX.npz'
data = np.load(filename)
data_GA = data["fx_array"]

avg_GA = calculate_average(data_GA)
print(f"Average GA: {avg_GA:.2f}")
# Out:
# Average GA: 1427959701.14

# %%
data = np.load('./results/solutions_1600_VNS.npz')['fx_array']
data_VNS = data[:30]

avg_VNS = calculate_average(data_VNS)
print(f"Average VNS: {avg_VNS:.2f}")
# Out:
# Average VNS: 1362673075.58

# %%
percentage_difference(avg_GA, avg_VNS)
# Out:
# +4.68%

# %% [markdown]
# ## Conclusion:

# %%
data = {
    "Problem Size": [100, 200, 400, 800, 1600],
    "GA": [77776643.81, 166214321.11, 342109926.27, 707805912.18, 1427959701.14],
    "VNS": [74474593.85, 152161681.82, 312538139.57, 658957131.23, 1363240244.41],
    "%": ["+4.34%", "+8.83%", "+9.03%", "+7.15%", "+4.64%"]
}

df = pd.DataFrame(data)

styled_df = df.style.format({
    "GA": "{:,.2f}",
    "VNS": "{:,.2f}"
}).set_properties(**{
    'text-align': 'center',
    'border': '1px solid black',
    'color': 'black',
    'background-color': '#ffffff'
}).set_table_styles([
    {
        'selector': 'th',
        'props': [
            ('border', '1px solid black'),
            ('background-color', '#f2f2f2'),
            ('color', 'black')
        ]
    },
    {
        'selector': 'td',
        'props': [
            ('color', 'black')
        ]
    }
])

styled_df
# Out:
# <style type="text/css">
# #T_f120d th {
#   border: 1px solid black;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_f120d td {
#   color: black;
# }
# #T_f120d_row0_col0, #T_f120d_row0_col1, #T_f120d_row0_col2, #T_f120d_row0_col3, #T_f120d_row1_col0, #T_f120d_row1_col1, #T_f120d_row1_col2, #T_f120d_row1_col3, #T_f120d_row2_col0, #T_f120d_row2_col1, #T_f120d_row2_col2, #T_f120d_row2_col3, #T_f120d_row3_col0, #T_f120d_row3_col1, #T_f120d_row3_col2, #T_f120d_row3_col3, #T_f120d_row4_col0, #T_f120d_row4_col1, #T_f120d_row4_col2, #T_f120d_row4_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #ffffff;
# }
# </style>
# <table id="T_f120d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f120d_level0_col0" class="col_heading level0 col0" >Problem Size</th>
#       <th id="T_f120d_level0_col1" class="col_heading level0 col1" >GA</th>
#       <th id="T_f120d_level0_col2" class="col_heading level0 col2" >VNS</th>
#       <th id="T_f120d_level0_col3" class="col_heading level0 col3" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f120d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f120d_row0_col0" class="data row0 col0" >100</td>
#       <td id="T_f120d_row0_col1" class="data row0 col1" >77,776,643.81</td>
#       <td id="T_f120d_row0_col2" class="data row0 col2" >74,372,047.02</td>
#       <td id="T_f120d_row0_col3" class="data row0 col3" >+4.48%</td>
#     </tr>
#     <tr>
#       <th id="T_f120d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f120d_row1_col0" class="data row1 col0" >200</td>
#       <td id="T_f120d_row1_col1" class="data row1 col1" >166,214,321.11</td>
#       <td id="T_f120d_row1_col2" class="data row1 col2" >150,573,108.65</td>
#       <td id="T_f120d_row1_col3" class="data row1 col3" >+9.87%</td>
#     </tr>
#     <tr>
#       <th id="T_f120d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f120d_row2_col0" class="data row2 col0" >400</td>
#       <td id="T_f120d_row2_col1" class="data row2 col1" >342,109,926.27</td>
#       <td id="T_f120d_row2_col2" class="data row2 col2" >312,118,194.03</td>
#       <td id="T_f120d_row2_col3" class="data row2 col3" >+9.17%</td>
#     </tr>
#     <tr>
#       <th id="T_f120d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f120d_row3_col0" class="data row3 col0" >800</td>
#       <td id="T_f120d_row3_col1" class="data row3 col1" >707,805,912.18</td>
#       <td id="T_f120d_row3_col2" class="data row3 col2" >657,535,079.08</td>
#       <td id="T_f120d_row3_col3" class="data row3 col3" >+7.36%</td>
#     </tr>
#     <tr>
#       <th id="T_f120d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f120d_row4_col0" class="data row4 col0" >1600</td>
#       <td id="T_f120d_row4_col1" class="data row4 col1" >1,427,959,701.14</td>
#       <td id="T_f120d_row4_col2" class="data row4 col2" >1,363,240,244.41</td>
#       <td id="T_f120d_row4_col3" class="data row4 col3" >+4.64%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## EXECUTION TIME VALUE

# %% [markdown]
# ## Problem size 100

# %%
filename = './new_results/GA_100_time.npz'
data = np.load(filename)
data_GA = data["fx_array"]

avg_GA = calculate_average(data_GA)
print(f"Average GA: {avg_GA:.2f}")
# Out:
# Average GA: 60480.38

# %%
data = np.load('../run_parallel/new_results/script_100_execution_time.npz')['fx_array']
data_VNS = data[:30]

avg_VNS = calculate_average(data_VNS)
print(f"Average VNS: {avg_VNS:.2f}")
# Out:
# Average VNS: 377.94

# %%
percentage_difference(avg_GA, avg_VNS)
# Out:
# +197.52%

# %% [markdown]
# ## Problem size 200

# %%
filename = './new_results/GA_200_time.npz'
data = np.load(filename)
data_GA = data["fx_array"]

avg_GA = calculate_average(data_GA)
print(f"Average GA: {avg_GA:.2f}")
# Out:
# Average GA: 23210.39

# %%
data = np.load('../run_parallel/new_results/script_200_execution_time.npz')['fx_array']
data_VNS = data[:30]

avg_VNS = calculate_average(data_VNS)
print(f"Average VNS: {avg_VNS:.2f}")
# Out:
# Average VNS: 1136.79

# %%
percentage_difference(avg_GA, avg_VNS)
# Out:
# +181.32%

# %% [markdown]
# ## Problem size 400

# %%
filename = './new_results/GA_400_time.npz'
data = np.load(filename)
data_GA = data["fx_array"]

avg_GA = calculate_average(data_GA)
print(f"Average GA: {avg_GA:.2f}")
# Out:
# Average GA: 27590.31

# %%
data = np.load('../run_parallel/new_results/script_400_execution_time.npz')['fx_array']
data_VNS = data[:30]

avg_VNS = calculate_average(data_VNS)
print(f"Average VNS: {avg_VNS:.2f}")
# Out:
# Average VNS: 3644.44

# %%
percentage_difference(avg_GA, avg_VNS)
# Out:
# +153.33%

# %% [markdown]
# ## Problem size 800

# %%
filename = './new_results/GA_800_time.npz'
data = np.load(filename)
data_GA = data["fx_array"]

avg_GA = calculate_average(data_GA)
print(f"Average GA: {avg_GA:.2f}")
# Out:
# Average GA: 48803.09

# %%
data = np.load('../run_parallel/new_results/script_800_execution_time.npz')['fx_array']
data_VNS = data[:30]

avg_VNS = calculate_average(data_VNS)
print(f"Average VNS: {avg_VNS:.2f}")
# Out:
# Average VNS: 10966.21

# %%
percentage_difference(avg_GA, avg_VNS)
# Out:
# +126.61%

# %% [markdown]
# ## Problem size 1600

# %%
data = {
    "Problem Size": [100, 200, 400, 800, 1600],
    "GA": [60480.38, 23210.39, 27590.31, 48803.09, 0],
    "VNS": [377.94, 1136.79, 3644.44, 10966.21, 0],
    "%": ["+197.52%", "+181.32%", "+153.33%", "+126.61%", "-%"]
}

df = pd.DataFrame(data)

styled_df = df.style.format({
    "GA": "{:,.2f}",
    "VNS": "{:,.2f}"
}).set_properties(**{
    'text-align': 'center',
    'border': '1px solid black',
    'color': 'black',
    'background-color': '#ffffff'
}).set_table_styles([
    {
        'selector': 'th',
        'props': [
            ('border', '1px solid black'),
            ('background-color', '#f2f2f2'),
            ('color', 'black')
        ]
    },
    {
        'selector': 'td',
        'props': [
            ('color', 'black')
        ]
    }
])

styled_df
# Out:
# <style type="text/css">
# #T_69a9e th {
#   border: 1px solid black;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_69a9e td {
#   color: black;
# }
# #T_69a9e_row0_col0, #T_69a9e_row0_col1, #T_69a9e_row0_col2, #T_69a9e_row0_col3, #T_69a9e_row1_col0, #T_69a9e_row1_col1, #T_69a9e_row1_col2, #T_69a9e_row1_col3, #T_69a9e_row2_col0, #T_69a9e_row2_col1, #T_69a9e_row2_col2, #T_69a9e_row2_col3, #T_69a9e_row3_col0, #T_69a9e_row3_col1, #T_69a9e_row3_col2, #T_69a9e_row3_col3, #T_69a9e_row4_col0, #T_69a9e_row4_col1, #T_69a9e_row4_col2, #T_69a9e_row4_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #ffffff;
# }
# </style>
# <table id="T_69a9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69a9e_level0_col0" class="col_heading level0 col0" >Problem Size</th>
#       <th id="T_69a9e_level0_col1" class="col_heading level0 col1" >GA</th>
#       <th id="T_69a9e_level0_col2" class="col_heading level0 col2" >VNS</th>
#       <th id="T_69a9e_level0_col3" class="col_heading level0 col3" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69a9e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69a9e_row0_col0" class="data row0 col0" >100</td>
#       <td id="T_69a9e_row0_col1" class="data row0 col1" >60,480.38</td>
#       <td id="T_69a9e_row0_col2" class="data row0 col2" >369.59</td>
#       <td id="T_69a9e_row0_col3" class="data row0 col3" >+197.57%</td>
#     </tr>
#     <tr>
#       <th id="T_69a9e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69a9e_row1_col0" class="data row1 col0" >200</td>
#       <td id="T_69a9e_row1_col1" class="data row1 col1" >23,210.39</td>
#       <td id="T_69a9e_row1_col2" class="data row1 col2" >1,192.69</td>
#       <td id="T_69a9e_row1_col3" class="data row1 col3" >+180.45%</td>
#     </tr>
#     <tr>
#       <th id="T_69a9e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69a9e_row2_col0" class="data row2 col0" >400</td>
#       <td id="T_69a9e_row2_col1" class="data row2 col1" >27,590.31</td>
#       <td id="T_69a9e_row2_col2" class="data row2 col2" >3,917.46</td>
#       <td id="T_69a9e_row2_col3" class="data row2 col3" >+150.27%</td>
#     </tr>
#     <tr>
#       <th id="T_69a9e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69a9e_row3_col0" class="data row3 col0" >800</td>
#       <td id="T_69a9e_row3_col1" class="data row3 col1" >48,803.09</td>
#       <td id="T_69a9e_row3_col2" class="data row3 col2" >11,512.24</td>
#       <td id="T_69a9e_row3_col3" class="data row3 col3" >+123.65%</td>
#     </tr>
#     <tr>
#       <th id="T_69a9e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_69a9e_row4_col0" class="data row4 col0" >1600</td>
#       <td id="T_69a9e_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_69a9e_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_69a9e_row4_col3" class="data row4 col3" >-%</td>
#     </tr>
#   </tbody>
# </table>
