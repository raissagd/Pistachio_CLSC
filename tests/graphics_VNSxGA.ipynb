# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import shapiro
plt.rcParams.update({'font.size': 20})

# %% [markdown]
# # VNS x GA

# %% [markdown]
# ## Instance 100

# %%
filename1 = './GAxVNS/results/solutions_100_VNS.npz'
data1 = np.load(filename1)
fx_array1 = data1["fx_array"]

filename2 = './GAxVNS/results/solutions_100_GA.npz'
data2 = np.load(filename2)
fx_array2 = data2["best_solutions"]

plt.figure(figsize=(10, 6))
plt.boxplot([fx_array1, fx_array2], positions=[1, 2])
plt.ylabel('Solution values')
plt.xticks([1, 2], ['VNS', 'GA'])
plt.title('Comparison between VNS and GA solutions: instance 100')
plt.legend()
plt.show()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_21456\2579133327.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
print(shapiro(fx_array1))
print(shapiro(fx_array2))
# Out:
# ShapiroResult(statistic=np.float64(0.6334626513438057), pvalue=np.float64(1.1724573743435957e-13))
# ShapiroResult(statistic=np.float64(0.9402768072342758), pvalue=np.float64(0.09253365835240603))

# %% [markdown]
# The VNS results are not normally distributed. GA's are.

# %%
# Mann-Whitney U test (for non-parametric data)
u_stat, p_value = stats.mannwhitneyu(fx_array1, fx_array2, alternative='less')

print(f'U-statistic: {u_stat}, p-value: {p_value}')
# Out:
# U-statistic: 888.0, p-value: 0.002579218558526756

# %% [markdown]
# The test suggests that the data in fx_array1 tend to be less than the data in fx_array2, and this difference is statistically significant.

# %% [markdown]
# ## Instance 200

# %%
filename1 = './GAxVNS/results/solutions_200_VNS.npz'
data1 = np.load(filename1)
fx_array1 = data1["fx_array"]

filename2 = './GAxVNS/results/solutions_200_GA.npz'
data2 = np.load(filename2)
fx_array2 = data2["best_solutions"]

plt.figure(figsize=(10, 6))
plt.boxplot([fx_array1, fx_array2], positions=[1, 2])
plt.ylabel('Solution values')
plt.xticks([1, 2], ['VNS', 'GA'])
plt.title('Comparison between VNS and GA solutions: instance 200')
plt.legend()
plt.show()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_21456\986410683.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
print(shapiro(fx_array1))
print(shapiro(fx_array2))
# Out:
# ShapiroResult(statistic=np.float64(0.9179660483166215), pvalue=np.float64(2.8380861506611112e-05))
# ShapiroResult(statistic=np.float64(0.8648806115446109), pvalue=np.float64(0.001291375920588146))

# %%
# Mann-Whitney U test (for non-parametric data)
u_stat, p_value = stats.mannwhitneyu(fx_array1, fx_array2, alternative='less')

print(f'U-statistic: {u_stat}, p-value: {p_value}')
# Out:
# U-statistic: 746.0, p-value: 0.0001273060087360223

# %% [markdown]
# The test suggests that the data in fx_array1 tend to be less than the data in fx_array2, and this difference is statistically significant.

# %% [markdown]
# ## Instance 400

# %%
filename1 = './GAxVNS/results/solutions_400_VNS.npz'
data1 = np.load(filename1)
fx_array1 = data1["fx_array"]

filename2 = './GAxVNS/results/solutions_400_GA_FX.npz'
data2 = np.load(filename2)
fx_array2 = data2["fx_array"]

plt.figure(figsize=(10, 6))
plt.boxplot([fx_array1, fx_array2], positions=[1, 2])
plt.ylabel('Solution values')
plt.xticks([1, 2], ['VNS', 'GA'])
plt.title('Comparison between VNS and GA solutions: instance 400')
# plt.legend()
plt.tight_layout()
plt.show()

# %%
print(shapiro(fx_array1))
print(shapiro(fx_array2))
# Out:
# ShapiroResult(statistic=np.float64(0.9918858461325073), pvalue=np.float64(0.8591865309932969))
# ShapiroResult(statistic=np.float64(0.9690386608382071), pvalue=np.float64(0.5132168912715226))

# %% [markdown]
# Normally distributed.

# %%
t_stat, p_value = stats.ttest_ind(fx_array1, fx_array2, alternative='less')
print(f't-statistic: {t_stat}, p-value: {p_value}')
# Out:
# t-statistic: -7.194176754650313, p-value: 3.129040687306383e-11

# %% [markdown]
# The mean of fx_array1 is significantly smaller than the mean of fx_array2.

# %% [markdown]
# ## Instance 800

# %%
filename1 = './GAxVNS/results/solutions_800_VNS.npz'
data1 = np.load(filename1)
fx_array1 = data1["fx_array"]

filename2 = './GAxVNS/results/solutions_800_GA_FX.npz'
data2 = np.load(filename2)
fx_array2 = data2["fx_array"]

plt.figure(figsize=(10, 6))
plt.boxplot([fx_array1, fx_array2], positions=[1, 2])
plt.ylabel('Solution values')
plt.xticks([1, 2], ['VNS', 'GA'])
plt.title('Comparison between VNS and GA solutions: instance 800')
plt.legend()
plt.show()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_21456\996788425.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
print(shapiro(fx_array1))
print(shapiro(fx_array2))
# Out:
# ShapiroResult(statistic=np.float64(0.9866618186272758), pvalue=np.float64(0.49221125030847496))
# ShapiroResult(statistic=np.float64(0.9463233284121313), pvalue=np.float64(0.13466618986468254))

# %% [markdown]
# Normally distributed.

# %%
t_stat, p_value = stats.ttest_ind(fx_array1, fx_array2, alternative='less')
print(f't-statistic: {t_stat}, p-value: {p_value}')
# Out:
# t-statistic: -9.638691691949857, p-value: 7.204087036803465e-17

# %% [markdown]
# The mean of fx_array1 is significantly smaller than the mean of fx_array2.

# %% [markdown]
# ## Instance 1600

# %%
filename1 = './GAxVNS/results/solutions_1600_VNS.npz'
data1 = np.load(filename1)
fx_array1 = data1["fx_array"]

filename2 = './GAxVNS/results/solutions_1600_GA_FX.npz'
data2 = np.load(filename2)
fx_array2 = data2["fx_array"]

plt.figure(figsize=(10, 6))
plt.boxplot([fx_array1, fx_array2], positions=[1, 2])
plt.ylabel('Solution values')
plt.xticks([1, 2], ['VNS', 'GA'])
plt.title('Comparison between VNS and GA solutions: instance 800')
plt.legend()
plt.show()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_21456\3613628770.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
print(shapiro(fx_array1))
print(shapiro(fx_array2))
# Out:
# ShapiroResult(statistic=np.float64(0.9772867010097734), pvalue=np.float64(0.11632218952622364))
# ShapiroResult(statistic=np.float64(0.9591463286655081), pvalue=np.float64(0.294545739617318))

# %% [markdown]
# Normally distributed.

# %%
t_stat, p_value = stats.ttest_ind(fx_array1, fx_array2, alternative='less')
print(f't-statistic: {t_stat}, p-value: {p_value}')
# Out:
# t-statistic: -10.736025824740693, p-value: 1.7853043419088597e-19

# %% [markdown]
# The mean of fx_array1 is significantly smaller than the mean of fx_array2.
