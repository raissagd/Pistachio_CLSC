# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})

# %% [markdown]
# # VNS x GUROBI

# %% [markdown]
# ## Instance 100

# %%
filename = './tests/run_parallel/results/script_100_fx_values.npz'
data = np.load(filename)
fx_array = data["fx_array"]

# Gurobi's solution
gurobi_sol = 70598781.55

plt.figure(figsize=(8, 6))
plt.boxplot(fx_array)
plt.scatter(1, gurobi_sol, color='red', s=100, label=f"Gurobi's solution: {gurobi_sol}")
plt.ylabel('Solution values')
plt.title('Comparison of 30 runs of the VNS with Gurobi: instance 100')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Instance 200

# %%
filename = './tests/run_parallel/results/script_200_fx_values.npz'
data = np.load(filename)
fx_array = data["fx_array"]

# Gurobi's solution
gurobi_sol = 137535570.42

plt.figure(figsize=(8, 6))
plt.boxplot(fx_array)
plt.scatter(1, gurobi_sol, color='red', s=100, label=f"Gurobi's solution: {gurobi_sol}")
plt.ylabel('Solution values')
plt.title('Comparison of 30 runs of the VNS with Gurobi: instance 200')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Instance 400

# %%
filename = './tests/run_parallel/results/script_400_fx_values.npz'
data = np.load(filename)
fx_array = data["fx_array"]

# Gurobi's solution
gurobi_sol = 270662192.84

plt.figure(figsize=(8, 6))
plt.boxplot(fx_array)
plt.scatter(1, gurobi_sol, color='red', s=100, label=f"Gurobi's solution: {gurobi_sol}")
plt.ylabel('Solution values')
plt.title('Comparison of 30 runs of the VNS with Gurobi: instance 400')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Instance 800

# %%
filename = './tests/run_parallel/results/script_800_fx_values.npz'
data = np.load(filename)
fx_array = data["fx_array"]

# Gurobi's solution
gurobi_sol = 547200537.38

plt.figure(figsize=(8, 6))
plt.boxplot(fx_array)
plt.scatter(1, gurobi_sol, color='red', s=100, label=f"Gurobi's solution: {gurobi_sol}")
plt.ylabel('Solution values')
plt.title('Comparison of 30 runs of the VNS with Gurobi: instance 800')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Instance 1600

# %%
filename = './tests/run_parallel/results/script_1600_fx_values.npz'
data = np.load(filename)
fx_array = data["fx_array"]

# Gurobi's solution
#gurobi_sol = 70598781.55

plt.figure(figsize=(8, 6))
plt.boxplot(fx_array)
#plt.scatter(1, gurobi_sol, color='red', s=100, label=f"Gurobi's solution: {gurobi_sol}")
plt.ylabel('Solution values')
plt.title('Comparison of 30 runs of the VNS with Gurobi: instance 1600')
plt.show()
