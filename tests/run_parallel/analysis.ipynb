# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 100

# %%
data = np.load('./results/script_100_fx_values.npz')

for key, value in data.items():
    median_value = np.median(value)
    print(f"Median value: {median_value}")
# Out:
# Median value: 73563017.04492697

# %%
data = np.load('./results/script_100_execution_time.npz')

for key, value in data.items():
    median_value = np.median(value)
    print(f"Median value: {median_value}")
# Out:
# Median value: 240.57673907279968

# %% [markdown]
# ### 200

# %%
data = np.load('./results/script_200_fx_values.npz')

for key, value in data.items():
    median_value = np.median(value)
    print(f"Median value: {median_value}")
# Out:
# Median value: 148844137.66365573

# %%
data = np.load('./results/script_200_execution_time.npz')

for key, value in data.items():
    median_value = np.median(value)
    print(f"Median value: {median_value}")
# Out:
# Median value: 714.4991488456726

# %% [markdown]
# ### 400

# %%
data = np.load('./results/script_400_fx_values.npz')

for key, value in data.items():
    median_value = np.median(value)
    print(f"Median value: {median_value}")
# Out:
# Median value: 307534381.60856926

# %%
data = np.load('./results/script_400_execution_time.npz')

for key, value in data.items():
    median_value = np.median(value)
    print(f"Median value: {median_value}")
# Out:
# Median value: 2015.7288582324982

# %% [markdown]
# ### 800

# %%
data = np.load('./results/script_800_fx_values.npz')

for key, value in data.items():
    median_value = np.median(value)
    print(f"Median value: {median_value}")
# Out:
# Median value: 657309254.8238914

# %%
data = np.load('./results/script_800_execution_time.npz')

for key, value in data.items():
    median_value = np.median(value)
    print(f"Median value: {median_value}")
# Out:
# Median value: 5537.29164481163

# %% [markdown]
# ### 1600

# %%
data = np.load('./results/script_1600_fx_values.npz')

for key, value in data.items():
    median_value = np.median(value)
    print(f"Median value: {median_value}")
# Out:
# Median value: 1364412771.1495688

# %%
data = np.load('./results/script_1600_execution_time.npz')

for key, value in data.items():
    median_value = np.median(value)
    print(f"Median value: {median_value}")
# Out:
# Median value: 17766.87371480465

# %% [markdown]
# ### Results

# %%
file_path = './results/fx_values.csv'
df = pd.read_csv(file_path)
print(df)
# Out:
#    Problem size        Gurobi           VNS Percentage
# 0           100    7059878.15  7.356017e+06      4.19%
# 1           200  137535570.42  1.488441e+08      8.22%
# 2           400  270662192.84  3.075344e+08     13.62%
# 3           800  547200537.38  6.573093e+08     20.12%
# 4          1600             -  1.364413e+09          -

# %%
file_path = './results/exec_time.csv'
df = pd.read_csv(file_path)
print(df)
# Out:
#    Problem size Gurobi           VNS Percentage
# 0           100    261    240.576739     -7.83%
# 1           200   3834    714.499149    -81.36%
# 2           400  70339   2015.728858    -97.13%
# 3           800  11836   5537.291645    -53.22%
# 4          1600      -  17766.873715          -
