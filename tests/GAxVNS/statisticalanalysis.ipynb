# %%
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt

# %%
ga = np.load('./new_results/GA_100_FX.npz')['fx_array']
vns = np.load('../run_parallel/new_results/script_100_fx_values.npz')['fx_array']
vns = vns[:30]

print(stats.shapiro(ga))
print(stats.shapiro(vns))
print(stats.ttest_ind(ga, vns, equal_var=False, alternative='greater'))
print(stats.mannwhitneyu(ga, vns, alternative='greater'))
# Out:
# ShapiroResult(statistic=np.float64(0.8402100292315624), pvalue=np.float64(0.00038938416228812537))
# ShapiroResult(statistic=np.float64(0.5476100415990921), pvalue=np.float64(1.773187901991437e-08))
# TtestResult(statistic=np.float64(3.3758015020460914), pvalue=np.float64(0.0006689066642841734), df=np.float64(56.414763728905776))
# MannwhitneyuResult(statistic=np.float64(789.0), pvalue=np.float64(2.799953550638792e-07))

# %%
plt.boxplot([ga, vns], tick_labels=['GA', 'VNS'], notch=True)
plt.ylabel('Objective Function Value')
plt.title('Comparison of GA and VNS')
plt.grid()
plt.show()
# Out:
# C:\Users\Andre\AppData\Local\Temp\ipykernel_19028\447682585.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([ga, vns], labels=['GA', 'VNS'], notch=True)
